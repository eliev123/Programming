# %% [markdown]
# # **First Jupyter Notebook**
# ## I really love markdown

# %%
print("This is my first notebook.")
# Out:
# This is my first notebook.

# %%
INTEGER=12

# %%
#sets print = 12
print(INTEGER)
# Out:
# 12

# %%
#sets FLOAT_PT=12
FLOAT_PT=12.0

# %%
#prints both INTEGER and FLOAT_PT
print (INTEGER, FLOAT_PT)
# Out:
# 12 12.0

# %%
STRING="The integer is"

# %%
print (STRING)
# Out:
# The integer is

# %%
#print the integer is 12 using variable name
print(STRING, INTEGER)
# Out:
# The integer is 12

# %%
print ("The sum is", INTEGER + FLOAT_PT)
# Out:
# The sum is 24.0

# %%
STRING2= 'This is a string.\n\n\n'
STRING3="This is \t\t\t also a string."
print(STRING2)
print(STRING3)
# Out:
# This is a string.
#
#
#
# This is 			 also a string.

# %%
print (STRING)
# Out:
# The integer is

# %%
print(STRING.lower())
# Out:
# the integer is

# %%
print (f"The interger is {INTEGER}, my favorite integer.")
# Out:
# The interger is 12, my favorite integer.

# %%
FIRST="Eli"
LAST="Valerius"
AGE=21

# %%
COMBINED=f"my name is {FIRST} {LAST} and I am {AGE} years old"
print (COMBINED)
# Out:
# my name is Eli Valerius and I am 21 years old

# %% [markdown]
# print(COMBINED.upper())

# %% [markdown]
# Creating my very first list, which is analogous to an array in bash. List, like arrays, are zero-based

# %%
#create list
STUDENTS=['Elie', 'John', 'Diddy']

# %%
#set who is in the list on index 2 (remember 0 based)
print(STUDENTS[2])
# Out:
# Diddy

# %%
#see all students on list
print(STUDENTS)
# Out:
# ['Elie', 'John', 'Diddy']

# %%
#create nested list
MY_NEST=[[1, 2, 3, 4], ['Eli', 'has', 'a', 'party'], ['Coding', 'is', 'life']]

# %%
#indexing into nested list
print(MY_NEST[0])
print(MY_NEST[1])
print(MY_NEST[2])
# Out:
# [1, 2, 3, 4]
# ['Eli', 'has', 'a', 'party']
# ['Coding', 'is', 'life']

# %%
#indexing into individual element in nexted list
print("Codiing is making me question my",MY_NEST[2][2])
# Out:
# Codiing is making me question my life

# %% [markdown]
# Lists are mutable. We can change things in our list. I want to add elements to my list. I will use a method called append to do this.

# %%
print(STUDENTS)
# Out:
# ['Elie', 'John', 'Diddy']

# %%
#the append method
STUDENTS.append('Kendrick')
print(STUDENTS)
# Out:
# ['Elie', 'John', 'Diddy', 'Kendrick']

# %% [markdown]
# #we can remove elements from a list. Use pop method
# **listname.pop**(#)

# %%
STUDENTS.pop(2)
# Out:
# 'Diddy'

# %%
print(STUDENTS)
# Out:
# ['Elie', 'John']

# %%
POPPED=STUDENTS.pop(1)

# %% [markdown]
# sometimes you want to reverse stuff. Use reverse method. reverse()

# %%
STUDENTS.reverse()

# %%
print(STUDENTS)
# Out:
# ['Elie']

# %%
BOLOGNA='oscar' #new string variable
BOLOGNA_LIST=[] #creates empty list

# %%
print(BOLOGNA)
print(BOLOGNA_LIST)
# Out:
# oscar
# []

# %%
#loops through string to crreate a list
for CHAR in BOLOGNA: #for varialbe character in cariable bologna
    BOLOGNA_LIST.append(CHAR)
#list indent to get ouf of loop

print("My bologna has a first name. It's", BOLOGNA_LIST, "."
# Out:
#   Cell In[109], line 6
#     print("My bologna has a first name. It's", BOLOGNA_LIST, "."
#                                                                 ^
# SyntaxError: incomplete input
